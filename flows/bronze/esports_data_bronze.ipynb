# %% [markdown]
# ## Importing Libraries

# %%
import os
import requests
import re
import time
import logging
import urllib3

from dotenv import load_dotenv

from bs4 import BeautifulSoup

from pyspark.sql import SparkSession

# %% [markdown]
# ## Loading Environment Variables

# %%
load_dotenv()

api_key = os.getenv("API_KEY")

# %% [markdown]
# ## Create Spark Session

# %%
spark = SparkSession.builder \
    .appName("esport_data_bronze") \
    .config("spark.executor.memory", "64g") \
    .getOrCreate()
# Out:
# 24/03/09 09:12:56 WARN Utils: Your hostname, pitta resolves to a loopback address: 127.0.1.1; using 192.168.100.7 instead (on interface enp6s0)
# 24/03/09 09:12:56 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/09 09:12:57 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Get Recent Tournaments Data

# %%
# Disable warnings
urllib3.disable_warnings()

# Set your API key and the API endpoint URL
api_endpoint = "http://api.esportsearnings.com/v0/LookupRecentTournaments"

# Load the offset from a file, or start from 0 if it doesn't exist
try:
    with open("../../data/bronze/offset/offset.txt", "r") as offset_file:
        offset = int(offset_file.read())
except FileNotFoundError:
    offset = 0

all_data = []

# Initialize parameters
batch_size = 100
max_retries = 5
retries = 0  # Initialize the retry counter

while retries < max_retries:
    # Set up the request parameters
    params = {
        "apikey": api_key,
        "offset": offset,
    }

    try:
        # Make the API request
        response = requests.get(api_endpoint, params=params, verify=False)
        
        # Check for successful response
        if response.status_code == 200:
            # Check if response content is b'' (empty bytes)
            if response.content == b'':
                print("No more data to retrieve")
                break
            data = response.json()
            # Check if data is empty
            if not data or data == b'':
                print("No more data to retrieve")
                break  # No more data to retrieve
            all_data.extend(data)  # Append the batch to the list
            offset += batch_size  # Increment the offset for the next batch
            print(f"Processed {offset} records")
        else:
            logging.error(f"API request failed with status code: {response.status_code}")
            retries += 1
            if retries < max_retries:
                print("Retrying in 5 seconds...")
                time.sleep(5)
    except Exception as e:
        logging.error(f"An error occurred: {e}")
        retries += 1
        if retries < max_retries:
            print("Retrying in 5 seconds...")
            time.sleep(5)

if retries == max_retries:
    logging.error("Max retries reached. Exiting.")

# Save the offset to a file for resuming later
with open("../../data/bronze/offset/offset.txt", "w") as offset_file:
    offset_file.write(str(offset))
    
# Create a DataFrame from the retrieved data
all_data = spark.createDataFrame(all_data)

# Save the DataFrame to CSV
all_data.coalesce(1).write.format("csv").option("header", "true").mode("overwrite").save('../../data/bronze/esports_tournaments/esports_tournaments_csv.csv')

# Save the DataFrame to Parquet
all_data.coalesce(1).write.format("parquet").option("header", "true").mode("overwrite").save('../../data/bronze/esports_tournaments/esports_tournaments_parquet.parquet')
# Out:
# Processed 100 records
# Processed 200 records
# Processed 300 records
# Processed 400 records
# Processed 500 records
# Processed 600 records
# Processed 700 records
# Processed 800 records
# Processed 900 records
# Processed 1000 records
# Processed 1100 records
# Processed 1200 records
# Processed 1300 records
# Processed 1400 records
# Processed 1500 records
# Processed 1600 records
# Processed 1700 records
# Processed 1800 records
# Processed 1900 records
# Processed 2000 records
# Processed 2100 records
# Processed 2200 records
# Processed 2300 records
# Processed 2400 records
# Processed 2500 records
# Processed 2600 records
# Processed 2700 records
# Processed 2800 records
# Processed 2900 records
# Processed 3000 records
# Processed 3100 records
# Processed 3200 records
# Processed 3300 records
# Processed 3400 records
# Processed 3500 records
# Processed 3600 records
# Processed 3700 records
# Processed 3800 records
# Processed 3900 records
# Processed 4000 records
# Processed 4100 records
# Processed 4200 records
# Processed 4300 records
# Processed 4400 records
# Processed 4500 records
# Processed 4600 records
# Processed 4700 records
# Processed 4800 records
# Processed 4900 records
# Processed 5000 records
# Processed 5100 records
# Processed 5200 records
# Processed 5300 records
# Processed 5400 records
# Processed 5500 records
# Processed 5600 records
# Processed 5700 records
# Processed 5800 records
# Processed 5900 records
# Processed 6000 records
# Processed 6100 records
# Processed 6200 records
# Processed 6300 records
# Processed 6400 records
# Processed 6500 records
# Processed 6600 records
# Processed 6700 records
# Processed 6800 records
# Processed 6900 records
# Processed 7000 records
# Processed 7100 records
# Processed 7200 records
# Processed 7300 records
# Processed 7400 records
# Processed 7500 records
# Processed 7600 records
# Processed 7700 records
# Processed 7800 records
# Processed 7900 records
# Processed 8000 records
# Processed 8100 records
# Processed 8200 records
# Processed 8300 records
# Processed 8400 records
# Processed 8500 records
# Processed 8600 records
# Processed 8700 records
# Processed 8800 records
# Processed 8900 records
# Processed 9000 records
# Processed 9100 records
# Processed 9200 records
# Processed 9300 records
# Processed 9400 records
# Processed 9500 records
# Processed 9600 records
# Processed 9700 records
# Processed 9800 records
# Processed 9900 records
# Processed 10000 records
# Processed 10100 records
# Processed 10200 records
# Processed 10300 records
# Processed 10400 records
# Processed 10500 records
# Processed 10600 records
# Processed 10700 records
# Processed 10800 records
# Processed 10900 records
# Processed 11000 records
# Processed 11100 records
# Processed 11200 records
# Processed 11300 records
# Processed 11400 records
# Processed 11500 records
# Processed 11600 records
# Processed 11700 records
# Processed 11800 records
# Processed 11900 records
# Processed 12000 records
# Processed 12100 records
# Processed 12200 records
# Processed 12300 records
# Processed 12400 records
# Processed 12500 records
# Processed 12600 records
# Processed 12700 records
# Processed 12800 records
# Processed 12900 records
# Processed 13000 records
# Processed 13100 records
# Processed 13200 records
# Processed 13300 records
# Processed 13400 records
# Processed 13500 records
# Processed 13600 records
# Processed 13700 records
# Processed 13800 records
# Processed 13900 records
# Processed 14000 records
# Processed 14100 records
# Processed 14200 records
# Processed 14300 records
# Processed 14400 records
# Processed 14500 records
# Processed 14600 records
# Processed 14700 records
# Processed 14800 records
# Processed 14900 records
# Processed 15000 records
# Processed 15100 records
# Processed 15200 records
# Processed 15300 records
# Processed 15400 records
# Processed 15500 records
# Processed 15600 records
# Processed 15700 records
# Processed 15800 records
# Processed 15900 records
# Processed 16000 records
# Processed 16100 records
# Processed 16200 records
# Processed 16300 records
# Processed 16400 records
# Processed 16500 records
# Processed 16600 records
# Processed 16700 records
# Processed 16800 records
# Processed 16900 records
# Processed 17000 records
# Processed 17100 records
# Processed 17200 records
# Processed 17300 records
# Processed 17400 records
# Processed 17500 records
# Processed 17600 records
# Processed 17700 records
# Processed 17800 records
# Processed 17900 records
# Processed 18000 records
# Processed 18100 records
# Processed 18200 records
# Processed 18300 records
# Processed 18400 records
# Processed 18500 records
# Processed 18600 records
# Processed 18700 records
# Processed 18800 records
# Processed 18900 records
# Processed 19000 records
# Processed 50300 records
# Processed 50400 records
# Processed 50500 records
# Processed 50600 records
# Processed 50700 records
# Processed 50800 records
# Processed 50900 records
# Processed 51000 records
# Processed 51100 records
# Processed 51200 records
# Processed 51300 records
# Processed 51400 records
# Processed 51500 records
# Processed 51600 records
# Processed 51700 records
# Processed 51800 records
# Processed 51900 records
# Processed 52000 records
# Processed 52100 records
# Processed 52200 records
# Processed 52300 records
# Processed 52400 records
# Processed 52500 records
# Processed 52600 records
# Processed 52700 records
# Processed 52800 records
# Processed 52900 records
# Processed 53000 records
# Processed 53100 records
# Processed 53200 records
# Processed 53300 records
# Processed 53400 records
# Processed 53500 records
# Processed 53600 records
# Processed 53700 records
# Processed 53800 records
# Processed 53900 records
# Processed 54000 records
# Processed 54100 records
# Processed 54200 records
# Processed 54300 records
# Processed 54400 records
# Processed 54500 records
# Processed 54600 records
# Processed 54700 records
# Processed 54800 records
# Processed 54900 records
# Processed 55000 records
# Processed 55100 records
# Processed 55200 records
# Processed 55300 records
# Processed 55400 records
# Processed 55500 records
# Processed 55600 records
# Processed 55700 records
# Processed 55800 records
# Processed 55900 records
# Processed 56000 records
# Processed 56100 records
# Processed 56200 records
# Processed 56300 records
# Processed 56400 records
# Processed 56500 records
# Processed 56600 records
# Processed 56700 records
# Processed 56800 records
# Processed 56900 records
# Processed 57000 records
# Processed 57100 records
# Processed 57200 records
# Processed 57300 records
# Processed 57400 records
# Processed 57500 records
# Processed 57600 records
# Processed 57700 records
# Processed 57800 records
# Processed 57900 records
# Processed 58000 records
# Processed 58100 records
# Processed 58200 records
# Processed 58300 records
# Processed 58400 records
# Processed 58500 records
# Processed 58600 records
# Processed 58700 records
# Processed 58800 records
# ERROR:root:API request failed with status code: 502
# Retrying in 5 seconds...
# Processed 58900 records
# Processed 59000 records
# Processed 59100 records
# Processed 59200 records
# Processed 59300 records
# Processed 59400 records
# Processed 59500 records
# Processed 59600 records
# Processed 59700 records
# Processed 59800 records
# Processed 59900 records
# Processed 60000 records
# Processed 60100 records
# Processed 60200 records
# Processed 60300 records
# Processed 60400 records
# Processed 60500 records
# Processed 60600 records
# Processed 60700 records
# Processed 60800 records
# Processed 60900 records
# Processed 61000 records
# Processed 61100 records
# Processed 61200 records
# Processed 61300 records
# Processed 61400 records
# Processed 61500 records
# Processed 61600 records
# Processed 61700 records
# Processed 61800 records
# Processed 61900 records
# Processed 62000 records
# Processed 62100 records
# Processed 62200 records
# Processed 62300 records
# Processed 62400 records
# Processed 62500 records
# Processed 62600 records
# Processed 62700 records
# Processed 62800 records
# Processed 62900 records
# Processed 63000 records
# Processed 63100 records
# Processed 63200 records
# Processed 63300 records
# Processed 63400 records
# Processed 63500 records
# Processed 63600 records
# Processed 63700 records
# Processed 63800 records
# Processed 63900 records
# Processed 64000 records
# Processed 64100 records
# No more data to retrieve
# 24/03/09 09:30:05 WARN TaskSetManager: Stage 0 contains a task of very large size (5746 KiB). The maximum recommended task size is 1000 KiB.
# 24/03/09 09:30:08 WARN TaskSetManager: Stage 1 contains a task of very large size (5746 KiB). The maximum recommended task size is 1000 KiB.

# %% [markdown]
# ## Get Games Awarding Prize Money

# %%
# Disable warnings
urllib3.disable_warnings()

# Read the parquet file to obtain the game_id values
parquet_data = spark.read.parquet('../../data/bronze/esports_tournaments/esports_tournaments_parquet.parquet')

# Extract the game_id column values into game_ids
game_ids = parquet_data.select('GameId').distinct().rdd.flatMap(lambda x: x).collect()

# Construct the URL for the current game ID
api_endpoint = "http://api.esportsearnings.com/v0/LookupGameById"

# Initialize the list to store game data
game_data = []

# Initialize parameters
max_retries = 5

for game_id in game_ids:
    
    # Set up the request parameters
    params = {
    "apikey": api_key,
    "gameid": game_id,
    }   
    
    retries = 0
    

    while retries < max_retries:
        try:
            # Send a GET request to the API
            response = requests.get(api_endpoint, params=params, verify=False)

            # Check if the request was successful (status code 200)
            if response.status_code == 200:
                # Parse the JSON response
                data = response.json()
                # Add the GameId to the data
                data["GameId"] = game_id
                # Append the data to the list of data entries
                game_data.append(data)
                # Print the status
                print(f"Processed game ID {game_id}")
                break
            else:
                logging.error(f"Request for game ID {game_id} failed with status code {response.status_code}")
                retries += 1
                if retries < max_retries:
                    logging.info(f"Retrying in 5 seconds (Retry {retries} of {max_retries})...")
                    time.sleep(5)
        except requests.exceptions.RequestException as e:
            # Handle connection and request exceptions
            logging.error(f"Request error for game ID {game_id}: {e}")
            retries += 1
            if retries < max_retries:
                logging.info(f"Retrying in 5 seconds (Retry {retries} of {max_retries})...")
                time.sleep(5)
                
# Create a DataFrame from the collected game data
game_data = spark.createDataFrame(game_data)
                
# Save the DataFrame to CSV
game_data.coalesce(1).write.format("csv").option("header", "true").mode("overwrite").save('../../data/bronze/esports_games_awarding_prize_money/games_awarding_prize_money_csv.csv')

# Save the DataFrame to Parquet
game_data.coalesce(1).write.format("parquet").option("header", "true").mode("overwrite").save('../../data/bronze/esports_games_awarding_prize_money/games_awarding_prize_money_parquet.parquet')
# Out:
# Processed game ID 558
# Processed game ID 541
# Processed game ID 191
# Processed game ID 418
# Processed game ID 730
# Processed game ID 270
# Processed game ID 222
# Processed game ID 705
# Processed game ID 442
# Processed game ID 367
# Processed game ID 243
# Processed game ID 348
# Processed game ID 415
# Processed game ID 277
# Processed game ID 847
# Processed game ID 656
# Processed game ID 502
# Processed game ID 831
# Processed game ID 167
# Processed game ID 385
# Processed game ID 155
# Processed game ID 736
# Processed game ID 857
# Processed game ID 564
# Processed game ID 588
# Processed game ID 241
# Processed game ID 602
# Processed game ID 347
# Processed game ID 237
# Processed game ID 724
# Processed game ID 330
# Processed game ID 530
# Processed game ID 198
# Processed game ID 414
# Processed game ID 823
# Processed game ID 487
# Processed game ID 486
# Processed game ID 196
# Processed game ID 427
# Processed game ID 677
# Processed game ID 858
# Processed game ID 532
# Processed game ID 635
# Processed game ID 184
# Processed game ID 853
# Processed game ID 463
# Processed game ID 693
# Processed game ID 399
# Processed game ID 188
# Processed game ID 529
# Processed game ID 274
# Processed game ID 202
# Processed game ID 228
# Processed game ID 406
# Processed game ID 262
# Processed game ID 624
# Processed game ID 734
# Processed game ID 570
# Processed game ID 691
# Processed game ID 421
# Processed game ID 638
# Processed game ID 600
# Processed game ID 264
# Processed game ID 650
# Processed game ID 229
# Processed game ID 799
# Processed game ID 676
# Processed game ID 617
# Processed game ID 231
# Processed game ID 387
# Processed game ID 640
# Processed game ID 483
# Processed game ID 354
# Processed game ID 802
# Processed game ID 476
# Processed game ID 660
# Processed game ID 832
# Processed game ID 793
# Processed game ID 545
# Processed game ID 189
# Processed game ID 534
# Processed game ID 798
# Processed game ID 578
# Processed game ID 566
# Processed game ID 569
# Processed game ID 633
# Processed game ID 204
# Processed game ID 251
# Processed game ID 707
# Processed game ID 666
# Processed game ID 259
# Processed game ID 366
# Processed game ID 647
# Processed game ID 787
# Processed game ID 837
# Processed game ID 728
# Processed game ID 725
# Processed game ID 571
# Processed game ID 522
# Processed game ID 527
# Processed game ID 183
# Processed game ID 240
# Processed game ID 263
# Processed game ID 396
# Processed game ID 839
# Processed game ID 336
# Processed game ID 698
# Processed game ID 612
# Processed game ID 788
# Processed game ID 667
# Processed game ID 584
# Processed game ID 152
# Processed game ID 416
# Processed game ID 357
# Processed game ID 267
# Processed game ID 757
# Processed game ID 808
# Processed game ID 261
# Processed game ID 398
# Processed game ID 489
# Processed game ID 625
# Processed game ID 531
# Processed game ID 669
# Processed game ID 619
# Processed game ID 572
# Processed game ID 394
# Processed game ID 751
# Processed game ID 786
# Processed game ID 169
# Processed game ID 758
# Processed game ID 273
# Processed game ID 456
# Processed game ID 739
# Processed game ID 458
# Processed game ID 340
# Processed game ID 526
# Processed game ID 469
# Processed game ID 211

# %% [markdown]
# ## Get Games Genres Data

# %%
from bs4 import BeautifulSoup
import requests
import pyspark.sql.functions as F

url = 'https://www.esportsearnings.com/games/browse-by-genre'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')

# Find all genre titles, game statistics, and game boxes
genre_titles = soup.find_all('span', class_='games_main_genre_title')
genre_stats = soup.find_all('span', class_='games_main_genre_stats')
game_boxes = soup.find_all('div', class_='games_main_game_box')
game_links = soup.find_all('a')

# Extract text and statistics as lists
genre_titles = [genre_title.text for genre_title in genre_titles]
genre_num = [int(re.search(r'\d+', genre_stat.text).group()) for genre_stat in genre_stats]
game_titles = [game_box['title'] for game_box in game_boxes if 'title' in game_box.attrs]
game_ids = [int(match.group(1)) for link in game_links if (match := re.compile(r'^/games/(\d+)').match(link.get('href')))]
# games_ids = spark.createDataFrame(game_ids, columns=['Game Id'])

# Initialize an empty list to store dictionaries
data = []

# Iterate through the pairs of genre titles and game boxes
position = 0
for genre_title, num_games in zip(genre_titles, genre_num):
    game_titles_list = game_titles[position:position + num_games]
    game_ids_list = game_ids[position:position + num_games]
    
    # Create a dictionary for each game and add it to the data list
    for game_title, game_id in zip(game_titles_list, game_ids_list):
        data.append({'Genre': genre_title, 'Game Name': game_title, 'Game Id': game_id})
    
    position += num_games

# Create a DataFrame from the list of dictionaries
df = spark.createDataFrame(data)

# Save the DataFrame to CSV
df.coalesce(1).write.format("csv").option("header", "true").mode("overwrite").save('../../data/bronze/esports_tournaments/game_genres_csv.csv')

# Save the DataFrame to Parquet
df.coalesce(1).write.format("parquet").option("header", "true").mode("overwrite").save('../../data/bronze/esports_tournaments/game_genres_parquet.parquet')

# %%
spark.stop()
